# %% [markdown]
# ## ODOC Public Inmate Data
#
#
# This notebook is intended as a start for research of the ODOC data.  To use this notebook, follow the setup instructiion found [here](https://github.com/codefortulsa/odoc-parse). Then download the data published [here](http://doc.publishpath.com/odoc-public-inmate-data).  Unzip the file and place the files in a subdirectory called 'data'.
#
# The set of files includes a ReadMe.txt which describes the files and their fixed formats. The sections of this notebook show description of each file and how to import it into pandas dataframes.  NOTE: the widths variables differ slighty from the description to handle some difference in the data.

# %%
import pandas as pd

# %% [markdown]
# ## Schedule A - Profile Data Layout
#  ```
#  =======================================================
#  Name                            Null?    Type
#  ------------------------------- -------- ----
#  DOC_NUM                         NOT NULL NUMBER(10)
#  LAST_NAME                                VARCHAR2(30)
#  FIRST_NAME                               VARCHAR2(30)
#  MIDDLE_NAME                              VARCHAR2(30)
#  SUFFIX                                   VARCHAR2(5)
#  LAST_MOVE_DATE                           DATE 'DD-MMM-YY' (9)
#  FACILITY                                 VARCHAR2(40)
#  BIRTH_DATE                               DATE 'DD-MMM-YY' (9)
#  SEX                                      VARCHAR2(1)
#  RACE                                     VARCHAR2(40)
#  HAIR                                     VARCHAR2(40)
#  HEIGHT_FT                                VARCHAR2(2)
#  HEIGHT_IN                                VARCHAR2(2)
#  WEIGHT                                   VARCHAR2(4)
#  EYE                                      VARCHAR2(40)
#  STATUS                                   VARCHAR2(10)
#  ```

# %%
file = 'data/Vendor_Profile_Sample_Text.dat'

# uncomment this line to use the full dataset
# file = 'data/Vendor_Profile_Extract_Text.dat'

names = [
    "DOC_NUM"       
    ,"LAST_NAME"     
    ,"FIRST_NAME"    
    ,"MIDDLE_NAME"   
    ,"SUFFIX"        
    ,"LAST_MOVE_DATE"
    ,"FACILITY"      
    ,"BIRTH_DATE"    
    ,"SEX"           
    ,"RACE"          
    ,"HAIR"          
    ,"HEIGHT_FT"     
    ,"HEIGHT_IN"     
    ,"WEIGHT"        
    ,"EYE"           
    ,"STATUS"
]
widths = [
    11,
    30,
    30,
    30,
    5,
    9,
    40,
    9,
    1,
    40,
    40,
    2,
    2,
    4,
    40,
    10
]

profile_df = pd.read_fwf(file, 
    header=None,
    widths=widths,
    names=names)
                 
profile_df.head(20)
# Out:
#     DOC_NUM LAST_NAME   FIRST_NAME MIDDLE_NAME SUFFIX LAST_MOVE_DATE  \
# 0    400000   KANNADY         CARL         NaN    NaN            NaN
# 1    400001     SMITH     ADOLPHUS      HOWARD    NaN            NaN
# 2    400002        LE        DAVID       SMITH    NaN            NaN
# 3    400003  PHILLIPS        CLINT       ALLEN    NaN            NaN
# 4    400005   COLEMAN         JOEL         NaN    NaN            NaN
# 5    400006     SMITH       DANIEL       DUANE    NaN      30-MAY-08
# 6    400007      HILL      MICHAEL         NaN    NaN            NaN
# 7    400009    MCLAIN       JOSEPH         NaN    NaN            NaN
# 8    400014   BLEDSOE         TONY         LEE    NaN      13-MAY-02
# 9    400019    BEVENS        KAREN     ANNETTE    NaN            NaN
# 10   400021     CLARK        JASON     DARNELL    NaN      04-JUN-10
# 11   400029     BROWN  CHRISTOPHER         NaN    NaN            NaN
# 12   400031     EATON       RONALD        GENE    NaN            NaN
# 13   400033   ENGLISH        SHERI         SUE    NaN      20-MAY-04
# 14   400037    TUCKER        KEVIN           B    NaN            NaN
# 15   400039  DIOSDADO         JUAN     RAMIRES    NaN      29-APR-03
# 16   400041     GREEN     CHARLENE           M    NaN            NaN
# 17   400045    FIELDS         KIRK       WAYNE    NaN      14-JAN-11
# 18   400049       FOX       TENIKA      YASHEA    NaN            NaN
# 19   400052    FIELDS        JAMES       ALRED    NaN      05-AUG-08
#
#     FACILITY BIRTH_DATE SEX      RACE    HAIR  HEIGHT_FT  HEIGHT_IN  WEIGHT  \
# 0   INACTIVE  06-SEP-56   M     WHITE   BROWN          6          0     210
# 1   INACTIVE  09-APR-71   M     BLACK   BLACK          5          7     155
# 2   INACTIVE  26-AUG-80   M     ASIAN   BLACK          5          6     150
# 3   INACTIVE  24-AUG-75   M     WHITE   BROWN          5          7     162
# 4   INACTIVE  15-JAN-67   M     WHITE  BLONDE          5          7     150
# 5   INACTIVE  14-DEC-74   M     WHITE   BROWN          6          3     205
# 6   INACTIVE  24-OCT-55   M     WHITE     RED          5          8     180
# 7   INACTIVE  12-DEC-76   M     WHITE     RED          5          3     145
# 8   INACTIVE  24-APR-77   M     WHITE  BLONDE          6          0     150
# 9   INACTIVE  07-OCT-61   F     WHITE   BROWN          5          2     140
# 10  INACTIVE  25-APR-80   M     BLACK   BLACK          5          9     176
# 11  INACTIVE  04-OCT-79   M     BLACK   BLACK          5          9     187
# 12  INACTIVE  07-FEB-52   M     WHITE   BROWN          5         10     230
# 13  INACTIVE  07-NOV-66   F     WHITE   BROWN          5          7     125
# 14  INACTIVE  12-SEP-72   M     WHITE  BLONDE          5          7     140
# 15  INACTIVE  13-JUN-74   M  HISPANIC   BLACK          5          3     158
# 16  INACTIVE  16-SEP-61   F     BLACK   BLACK          5          0     185
# 17  INACTIVE  08-NOV-59   M     BLACK   BLACK          6          2     240
# 18  INACTIVE  26-AUG-81   F     BLACK   BLACK          5          3     180
# 19  INACTIVE  09-NOV-65   M     BLACK   BLACK          5         11     165
#
#       EYE    STATUS
# 0   GREEN  Inactive
# 1   BROWN  Inactive
# 2   BROWN  Inactive
# 3   BROWN  Inactive
# 4   BROWN  Inactive
# 5   BROWN  Inactive
# 6   BROWN  Inactive
# 7    BLUE  Inactive
# 8   HAZEL  Inactive
# 9    BLUE  Inactive
# 10  BROWN  Inactive
# 11  BROWN  Inactive
# 12  BROWN  Inactive
# 13   BLUE  Inactive
# 14   BLUE  Inactive
# 15  BROWN  Inactive
# 16  BROWN  Inactive
# 17  BROWN  Inactive
# 18    NaN  Inactive
# 19  BLACK  Inactive

# %% [markdown]
# ## Schedule B - Alias Data Layout
# ```
# =======================================================
#  Name                            Null?    Type
#  ------------------------------- -------- ----
#  DOC_NUM                         NOT NULL NUMBER(10)
#  LAST_NAME                                VARCHAR2(30)
#  FIRST_NAME                               VARCHAR2(30)
#  MIDDLE_NAME                              VARCHAR2(30)
#  SUFFIX                                   VARCHAR2(5)
# ```

# %%
file = 'data/Vendor_Alias_Sample_Text.dat'

# uncomment this line to use the full dataset
# file = 'data/Vendor_Alias_Extract_Text.dat'

names = [
         "DOC_NUM",
         "LAST_NAME",
         "FIRST_NAME",
         "MIDDLE_NAME",
         "SUFFIX"
]

widths = [
          11,
          30,
          30,
          30,
          5
]

alias_df = pd.read_fwf(file, 
    header=None,
    widths=widths,
    names=names)
                 
alias_df.head(20)
# Out:
#     DOC_NUM LAST_NAME   FIRST_NAME MIDDLE_NAME SUFFIX
# 0    400000   KANNADY         CARL         NaN    NaN
# 1    400001     SMITH     ADOLPHUS      HOWARD    NaN
# 2    400002        LE        DAVID       SMITH    NaN
# 3    400003  PHILLIPS        CLINT       ALLEN    NaN
# 4    400005   COLEMAN         JOEL         NaN    NaN
# 5    400006     SMITH       DANIEL       DUANE     JR
# 6    400006     SMITH       DANIEL       DUANE    NaN
# 7    400006     SMITH       DANIEL     DUANEJR    NaN
# 8    400007      HILL      MICHAEL         NaN    NaN
# 9    400009    MCLAIN       JOSEPH         NaN    NaN
# 10   400014   BLEDSOE        TOMMY         LEE    NaN
# 11   400014   BLEDSOE         TONY          CL    NaN
# 12   400014   BLEDSOE         TONY     COLEMAN    NaN
# 13   400014   BLEDSOE         TONY  COLMAN LEE    NaN
# 14   400014   BLEDSOE         TONY         LEE    NaN
# 15   400019    BEVENS        KAREN     ANNETTE    NaN
# 16   400021     CLARK        JASON     DARNELL    NaN
# 17   400029     BROWN  CHRISTOPHER         NaN    NaN
# 18   400031     EATON       RONALD        GENE    NaN
# 19   400033   ENGLISH        SHERI         SUE    NaN

# %% [markdown]
# ## Schedule C - Sentence Data Layout
# ```
# =======================================================
# Incarcerated_Term_In_Years = 9999 indicates a death sen
# tence
#
# Incarcerated_Term_In_Years = 8888 indicates a life with
# out parole sentence
#
# Incarcerated_Term_In_Years = 7777 indicates a life sent
# ence
# =======================================================
#  Name                            Null?    Type
#  ------------------------------- -------- ----
#  DOC_NUM                         NOT NULL NUMBER(10)
#  STATUTE_CODE                    NOT NULL VARCHAR2(40)
#  SENTENCING_COUNTY                        VARCHAR2(40)
#  JS_DATE                                  DATE 'YYYYMMDD' (8)
#  CRF_NUMBER                               VARCHAR2(40)
#  INCARCERATED_TERM_IN_YEARS               NUMBER(10,2)
#  PROBATION_TERM_IN_YEARS                  NUMBER(10,2)
#  ```

# %%
file = 'data/Vendor_sentence_Sample_Text.dat'

# uncomment this line to use the full dataset
# file = 'data/Vendor_sentence_Extract_Text.dat'

names =[
    "DOC_NUM",                   
    "STATUTE_CODE",              
    "SENTENCING_COUNTY",         
    "JS_DATE",                   
    "CRF_NUMBER",                
    "INCARCERATED_TERM_IN_YEARS",
    "PROBATION_TERM_IN_YEARS"
]


# first char in file is blank so offset by one in DOC_NUM field
widths = [
    11,
    40,
    40,
    9,
    40,
    13,
    13
]

sentence_df = pd.read_fwf(file, 
    header=None,
    widths=widths,
    names=names)
                 
sentence_df.head(20)
# Out:
#     DOC_NUM STATUTE_CODE        SENTENCING_COUNTY    JS_DATE  CRF_NUMBER  \
# 0    400000    21-1123.A    ARKANSAS JURISDICTION  05-FEB-97   1996-2007
# 1    400001      21-1435    COLORADO JURISDICTION  30-APR-01  00CR668-18
# 2    400002      21-1731    OKLAHOMA COUNTY COURT  15-JUN-01   2000-6699
# 3    400003       21-797       TEXAS JURISDICTION  30-APR-01     B28,824
# 4    400005      21-1713    MUSKOGEE COUNTY COURT  19-JUN-01   1999-1078
# 5    400006      21-1544  WASHINGTON COUNTY COURT  21-JUN-01    1999-171
# 6    400006      21-1544  WASHINGTON COUNTY COURT  19-JUN-06    1999-171
# 7    400006     15-765.3       TULSA COUNTY COURT  27-OCT-04   2004-2092
# 8    400006     15-765.3       TULSA COUNTY COURT  27-OCT-04   2004-2182
# 9    400006      21-1542  WASHINGTON COUNTY COURT  21-JUN-01      99-171
# 10   400006  47-11-902.C       TULSA COUNTY COURT  22-MAY-18  CF-2018-40
# 11   400006      21-1544  WASHINGTON COUNTY COURT  21-JUN-01    1999-171
# 12   400007      21-1705    MUSKOGEE COUNTY COURT  21-JUN-01    2001-309
# 13   400007      21-1713    MUSKOGEE COUNTY COURT  21-JUN-01    2001-309
# 14   400009     63-2-402    MUSKOGEE COUNTY COURT  18-JUN-01     2000-73
# 15   400009     63-2-405    MUSKOGEE COUNTY COURT  18-JUN-01     2000-73
# 16   400009       21-853    MUSKOGEE COUNTY COURT  18-JUN-01     2000-73
# 17   400009     63-2-402    MUSKOGEE COUNTY COURT  01-JUN-04     2000-73
# 18   400009       21-455    MUSKOGEE COUNTY COURT  01-JUN-04     2003-69
# 19   400014     63-2-402       TULSA COUNTY COURT  03-AUG-01    2001-539
#
#     INCARCERATED_TERM_IN_YEARS  PROBATION_TERM_IN_YEARS
# 0                          NaN                     9.95
# 1                          NaN                     3.00
# 2                          NaN                     1.00
# 3                          NaN                     3.00
# 4                          NaN                     3.00
# 5                          NaN                     5.00
# 6                          NaN                     5.00
# 7                          8.0                      NaN
# 8                          8.0                      NaN
# 9                          2.0                     3.00
# 10                         NaN                     4.00
# 11                         NaN                    10.00
# 12                         NaN                     1.00
# 13                         NaN                     1.00
# 14                         NaN                     3.00
# 15                         NaN                     3.00
# 16                         NaN                     3.00
# 17                         NaN                    10.00
# 18                         NaN                    10.00
# 19                         2.0                      NaN

# %% [markdown]
# Schedule D - Offense Codes Layout
# =======================================================
#  ```
#  Name                            Null?    Type
#  ------------------------------- -------- ----
#  STATUTE_CODE                    NOT NULL VARCHAR2(38)
#  DESCRIPTION                     NOT NULL VARCHAR2(40)
#  VIOLENT                                  VARCHAR2(1)
# ```

# %%
# NOTE:  No sample file for this data

file = 'data/Vendor_Offense_Extract_Text.dat'


names = [
    "STATUTE_CODE",
    "DESCRIPTION", 
    "VIOLENT",
]

widths = [
    38,
    40,
    1
]

offense_df = pd.read_fwf(file, 
    header=None,
    widths=widths,
    names=names)
                 
offense_df.head(20)
# Out:
#      STATUTE_CODE                               DESCRIPTION VIOLENT
# 0             0-0               UNKNOWN - FOR WARRANTS ONLY       N
# 1         10-1144         ACTS CAUSING JUVENILE DELINQUENCY       N
# 2         10-1627             DEPRIVATION OF LAWFUL CUSTODY       N
# 3           10-26   UNLAWFUL ASSUMPTION OF CUSTODY OF CHILD       N
# 4        10-404.1  SEX OFFENDER PROVIDING SERVICES TO CHILD       N
# 5          10-410  OPERATING CHILD CARE FACILITY W/O LICENS       N
# 6           10-71                       PATERNITY COMPLAINT       N
# 7         10-7103                   FAILURE TO REPORT CHILD       N
# 8         10-7115                               CHILD ABUSE       Y
# 9    10-7303-1.1B  REFUSE TO ASSUME CUSTODY OF CHILD IN DET       N
# 10  10A-2-7-611.B      PROHIBITED ITEMS JUVENILE FACILITIES       N
# 11       13-176.3      VIOLATING SECURITY OF COMMUNICATIONS       N
# 12     13-176.3.8    UNLAWFUL USE OF COMMUNICATION FACILITY       N
# 13       13-176.7   USE OF COMMUNICATION FACILITY TO COMMIT       N
# 14         15-751         CONSUMER PROTECTION ACT VIOLATION       N
# 15         15-753         CONSUMER PROTECTION ACT VIOLATION       N
# 16       15-765.3                         HOME REPAIR FRAUD       N
# 17         15-767      CONDUCT CLOSING OUT SALE W/O LICENSE       N
# 18      18-1020.F  CORP. FAILING TO FILE REAL ESTATE STATEM       N
# 19      18-552.11         FRAUDULENT USE OF NAME IN CHARITY       N

# %% [markdown]
# ## Examples
#
# - profile_df:  demographics
# - alias_df:
# - sentence_df: statute
# - offense_df
#
# NOTE:  Don't forget, these examples are based on sample data.

# %%
active_inmates = profile_df.query("STATUS == 'Active'")

joined_df = pd.merge(active_inmates, sentence_df, on='DOC_NUM', how='left')
joined_df.head(20)
# Out:
#     DOC_NUM LAST_NAME FIRST_NAME  MIDDLE_NAME SUFFIX LAST_MOVE_DATE  \
# 0    400088       LEE   JENNIFER     SUE LYNN    NaN      24-DEC-02
# 1    400088       LEE   JENNIFER     SUE LYNN    NaN      24-DEC-02
# 2    400088       LEE   JENNIFER     SUE LYNN    NaN      24-DEC-02
# 3    400088       LEE   JENNIFER     SUE LYNN    NaN      24-DEC-02
# 4    400088       LEE   JENNIFER     SUE LYNN    NaN      24-DEC-02
# 5    400094  KITTRELL      DAVID  CHRISTOPHER    NaN      26-FEB-19
# 6    400094  KITTRELL      DAVID  CHRISTOPHER    NaN      26-FEB-19
# 7    400094  KITTRELL      DAVID  CHRISTOPHER    NaN      26-FEB-19
# 8    400094  KITTRELL      DAVID  CHRISTOPHER    NaN      26-FEB-19
# 9    400094  KITTRELL      DAVID  CHRISTOPHER    NaN      26-FEB-19
# 10   400094  KITTRELL      DAVID  CHRISTOPHER    NaN      26-FEB-19
# 11   400094  KITTRELL      DAVID  CHRISTOPHER    NaN      26-FEB-19
# 12   400097    THOMAS     DUSTIN          NaN    NaN      27-DEC-19
# 13   400099  STEPHENS       GARY            K    NaN      01-SEP-17
# 14   400099  STEPHENS       GARY            K    NaN      01-SEP-17
#
#                                    FACILITY BIRTH_DATE SEX             RACE  \
# 0                     TULSA COUNTY DISTRICT  26-SEP-72   F            WHITE
# 1                     TULSA COUNTY DISTRICT  26-SEP-72   F            WHITE
# 2                     TULSA COUNTY DISTRICT  26-SEP-72   F            WHITE
# 3                     TULSA COUNTY DISTRICT  26-SEP-72   F            WHITE
# 4                     TULSA COUNTY DISTRICT  26-SEP-72   F            WHITE
# 5   DAVIS CORRECTIONAL FACILITY-HOLDENVILLE  05-APR-82   M            WHITE
# 6   DAVIS CORRECTIONAL FACILITY-HOLDENVILLE  05-APR-82   M            WHITE
# 7   DAVIS CORRECTIONAL FACILITY-HOLDENVILLE  05-APR-82   M            WHITE
# 8   DAVIS CORRECTIONAL FACILITY-HOLDENVILLE  05-APR-82   M            WHITE
# 9   DAVIS CORRECTIONAL FACILITY-HOLDENVILLE  05-APR-82   M            WHITE
# 10  DAVIS CORRECTIONAL FACILITY-HOLDENVILLE  05-APR-82   M            WHITE
# 11  DAVIS CORRECTIONAL FACILITY-HOLDENVILLE  05-APR-82   M            WHITE
# 12           CIMARRON CORRECTIONAL FACILITY  29-DEC-78   M  NATIVE AMERICAN
# 13           NORTH FORK CORRECTIONAL CENTER  11-FEB-50   M            WHITE
# 14           NORTH FORK CORRECTIONAL CENTER  11-FEB-50   M            WHITE
#
#     ... HEIGHT_IN  WEIGHT    EYE  STATUS STATUTE_CODE    SENTENCING_COUNTY  \
# 0   ...         1     134   BLUE  Active     63-2-402   TULSA COUNTY COURT
# 1   ...         1     134   BLUE  Active     63-2-402   TULSA COUNTY COURT
# 2   ...         1     134   BLUE  Active     63-2-402   TULSA COUNTY COURT
# 3   ...         1     134   BLUE  Active     63-2-402   TULSA COUNTY COURT
# 4   ...         1     134   BLUE  Active       21-440   TULSA COUNTY COURT
# 5   ...         8     161   BLUE  Active     63-2-402  OTTAWA COUNTY COURT
# 6   ...         8     161   BLUE  Active     63-2-402  OTTAWA COUNTY COURT
# 7   ...         8     161   BLUE  Active  63-2-402.B2  OTTAWA COUNTY COURT
# 8   ...         8     161   BLUE  Active     63-2-401  OTTAWA COUNTY COURT
# 9   ...         8     161   BLUE  Active     63-2-402  OTTAWA COUNTY COURT
# 10  ...         8     161   BLUE  Active    10-7115ST  OTTAWA COUNTY COURT
# 11  ...         8     161   BLUE  Active     63-2-402  OTTAWA COUNTY COURT
# 12  ...         7     204  BROWN  Active     21-701.7  COTTON COUNTY COURT
# 13  ...         6     200  BROWN  Active      21-1115  COTTON COUNTY COURT
# 14  ...         6     200  BROWN  Active      21-1115  COTTON COUNTY COURT
#
#       JS_DATE CRF_NUMBER INCARCERATED_TERM_IN_YEARS PROBATION_TERM_IN_YEARS
# 0   18-JUN-01   2001-922                        NaN                    2.00
# 1   26-APR-02   2001-922                        2.0                     NaN
# 2   24-DEC-02   2001-922                        NaN                    0.28
# 3   15-JAN-15  2014-4731                        NaN                    4.00
# 4   23-APR-18  2018-0296                        NaN                    3.00
# 5   22-JUN-01   2001-168                        NaN                    2.00
# 6   17-JAN-03   2001-168                        NaN                   10.00
# 7   17-JAN-03   2001-168                        NaN                   10.00
# 8   16-JAN-13   2002-146                        NaN                   10.00
# 9   16-JAN-13   2002-146                        NaN                   10.00
# 10  05-OCT-05   2005-318                       20.0                     NaN
# 11  05-OCT-05   2005-319                       20.0                     NaN
# 12  07-JUN-01    1999-46                     8888.0                     NaN
# 13  21-MAY-01    2000-20                       50.0                     NaN
# 14  21-MAY-01    2000-20                       50.0                     NaN
#
# [15 rows x 22 columns]

# %%
import numpy as np

import matplotlib.pyplot as plt


graph_df = joined_df.groupby(['RACE'])['DOC_NUM'].count()
graph_df.plot.pie(y='RACE', figsize=(5, 5))
