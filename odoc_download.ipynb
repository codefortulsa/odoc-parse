# %% [markdown]
# ## ODOC Public Inmate Data
#
#
# This notebook is intended as a start for research of the ODOC data.  To use this notebook, follow the setup instructiion found [here](https://github.com/codefortulsa/odoc-parse). Then download the data published [here](http://doc.publishpath.com/odoc-public-inmate-data).  Unzip the file and place the files in a subdirectory called 'data'.
#
# The set of files includes a ReadMe.txt which describes the files and their fixed formats. The sections of this notebook show description of each file and how to import it into pandas dataframes.  NOTE: the widths variables differ slighty from the description to handle some difference in the data.

# %%
import pandas as pd

# %% [markdown]
# ## Schedule A - Profile Data Layout
#  ```
#  =======================================================
#  Name                            Null?    Type
#  ------------------------------- -------- ----
#  DOC_NUM                         NOT NULL NUMBER(10)
#  LAST_NAME                                VARCHAR2(30)
#  FIRST_NAME                               VARCHAR2(30)
#  MIDDLE_NAME                              VARCHAR2(30)
#  SUFFIX                                   VARCHAR2(5)
#  LAST_MOVE_DATE                           DATE 'DD-MMM-YY' (9)
#  FACILITY                                 VARCHAR2(40)
#  BIRTH_DATE                               DATE 'DD-MMM-YY' (9)
#  SEX                                      VARCHAR2(1)
#  RACE                                     VARCHAR2(40)
#  HAIR                                     VARCHAR2(40)
#  HEIGHT_FT                                VARCHAR2(2)
#  HEIGHT_IN                                VARCHAR2(2)
#  WEIGHT                                   VARCHAR2(4)
#  EYE                                      VARCHAR2(40)
#  STATUS                                   VARCHAR2(10)
#  ```

# %%
file = 'data/Vendor_Profile_Sample_Text.dat'

# uncomment this line to use the full dataset
file = 'data/Vendor_Profile_Extract_Text.dat'

names = [
    "DOC_NUM"       
    ,"LAST_NAME"     
    ,"FIRST_NAME"    
    ,"MIDDLE_NAME"   
    ,"SUFFIX"        
    ,"LAST_MOVE_DATE"
    ,"FACILITY"      
    ,"BIRTH_DATE"    
    ,"SEX"           
    ,"RACE"          
    ,"HAIR"          
    ,"HEIGHT_FT"     
    ,"HEIGHT_IN"     
    ,"WEIGHT"        
    ,"EYE"           
    ,"STATUS"
]
widths = [
    11,
    30,
    30,
    30,
    5,
    9,
    40,
    9,
    1,
    40,
    40,
    2,
    2,
    4,
    40,10
]

profile_df = pd.read_fwf(file, 
    header=None,
    widths=widths,
    names=names)
                 
profile_df.head(20)
# Out:
#     DOC_NUM  LAST_NAME FIRST_NAME MIDDLE_NAME SUFFIX LAST_MOVE_DATE  \
# 0      8359     MESLES     ARDELL         NaN    NaN      03-MAR-86
# 1     10337     SAWYER      FRANK           N    NaN      12-JUN-91
# 2     12556    GOFORTH     PAMELA           B    NaN      13-NOV-89
# 3     20413   KNIGHTON    RAYMOND           J    NaN      18-APR-80
# 4     22574   STOCKTON     MELVIN           H    NaN      02-JAN-97
# 5     22663      MACON     EUGENE         NaN    NaN      30-MAR-98
# 6     27399     GARCIA       JOSE           L    NaN      11-JUL-16
# 7     27486      HIXON      BILLY           J    NaN      24-SEP-88
# 8     31179  GREENWOOD     BUFORD         NaN    NaN      20-NOV-80
# 9     32038     HOOPER        DON           V    NaN      06-AUG-82
# 10    32238  STAMPHILL       DALE         NaN    NaN      12-JAN-93
# 11    34928     WRIGHT  NATHANIEL         NaN    NaN      26-SEP-94
# 12    35018   WILLIAMS      FRANK         NaN    NaN      07-APR-78
# 13    35116    MACKLIN      HAMAN           X    NaN      03-MAY-86
# 14    35374      BLOCK     JESSIE         NaN    NaN      22-APR-89
# 15    38581      DUFFY     ROBERT           L    NaN      03-JUL-96
# 16    38615   MCINTIRE       JOHN           L    NaN      22-DEC-80
# 17    40289     YEAGER    WILLIAM      HAROLD    NaN      09-OCT-98
# 18    42571    FRAZIER       DAVE         NaN     JR      03-APR-92
# 19    42828     WILSON        ROY         NaN    NaN      05-FEB-93
#
#                                  FACILITY BIRTH_DATE SEX             RACE  \
# 0                                INACTIVE  06-APR-87   M              NaN
# 1                                INACTIVE  01-JAN-00   M            WHITE
# 2                                INACTIVE  06-FEB-51   M  NATIVE AMERICAN
# 3                                INACTIVE  20-AUG-48   M            BLACK
# 4                                INACTIVE  07-DEC-45   M            WHITE
# 5                                INACTIVE  26-JUL-39   M            BLACK
# 6   NORTH FORK CORRECTIONAL CENTER ESCAPE  11-SEP-43   M         HISPANIC
# 7                                INACTIVE  18-DEC-45   M            WHITE
# 8                                INACTIVE  13-MAR-17   M            BLACK
# 9                                INACTIVE  11-FEB-47   M            WHITE
# 10                               INACTIVE  11-MAR-12   M            WHITE
# 11                               INACTIVE  03-APR-11   M            BLACK
# 12                               INACTIVE  10-AUG-11   M            WHITE
# 13                               INACTIVE  01-JAN-00   M            BLACK
# 14                               INACTIVE  20-DEC-12   M            BLACK
# 15                               INACTIVE  01-AUG-25   M            BLACK
# 16                               INACTIVE  24-MAY-14   M            WHITE
# 17                               INACTIVE  29-OCT-14   M            WHITE
# 18                               INACTIVE  04-JAN-21   M            BLACK
# 19                               INACTIVE  03-JAN-21   M            BLACK
#
#           HAIR  HEIGHT_FT  HEIGHT_IN  WEIGHT    EYE    STATUS
# 0          NaN        NaN        NaN     NaN    NaN  Inactive
# 1          UNK        5.0        1.0     NaN  BLACK  Inactive
# 2        BROWN        5.0        9.0   116.0    N/R  Inactive
# 3        BROWN        NaN        NaN     NaN  BROWN  Inactive
# 4        BROWN        5.0       10.0   150.0   GRAY  Inactive
# 5          UNK        5.0       10.0     NaN    N/R  Inactive
# 6        BLACK        5.0        8.0   165.0  BROWN    Active
# 7        BROWN        5.0       10.0   160.0    N/R  Inactive
# 8        BLACK        5.0        9.0   207.0    N/R  Inactive
# 9        BROWN        5.0        8.0   150.0    N/R  Inactive
# 10  GRAY, ETC.        5.0        7.0   165.0  BROWN  Inactive
# 11       BLACK        5.0        9.0   162.0  BROWN  Inactive
# 12        BALD        5.0        7.0   150.0    N/R  Inactive
# 13         UNK        5.0       11.0   143.0    N/R  Inactive
# 14       BLACK        5.0        8.0   121.0  BROWN  Inactive
# 15  GRAY, ETC.        5.0        9.0   155.0  BROWN  Inactive
# 16  GRAY, ETC.        5.0       10.0   234.0    N/R  Inactive
# 17  GRAY, ETC.        5.0        7.0   158.0   BLUE  Inactive
# 18       BLACK        5.0       11.0   180.0  BROWN  Inactive
# 19  GRAY, ETC.        5.0       10.0   201.0  BROWN  Inactive

# %% [markdown]
# ## Schedule B - Alias Data Layout
# ```
# =======================================================
#  Name                            Null?    Type
#  ------------------------------- -------- ----
#  DOC_NUM                         NOT NULL NUMBER(10)
#  LAST_NAME                                VARCHAR2(30)
#  FIRST_NAME                               VARCHAR2(30)
#  MIDDLE_NAME                              VARCHAR2(30)
#  SUFFIX                                   VARCHAR2(5)
# ```

# %%
file = 'data/Vendor_Alias_Sample_Text.dat'

# uncomment this line to use the full dataset
# file = 'data/Vendor_Alias_Extract_Text.dat'

names = ["DOC_NUM", "LAST_NAME", "FIRST_NAME", "MIDDLE_NAME","SUFFIX"
]

widths = [ 11, 30, 30, 30, 5]

alias_df = pd.read_fwf(file, 
    header=None,
    widths=widths,
    names=names)
                 
alias_df.head(20)
# Out:
#     DOC_NUM LAST_NAME   FIRST_NAME MIDDLE_NAME SUFFIX
# 0    400000   KANNADY         CARL         NaN    NaN
# 1    400001     SMITH     ADOLPHUS      HOWARD    NaN
# 2    400002        LE        DAVID       SMITH    NaN
# 3    400003  PHILLIPS        CLINT       ALLEN    NaN
# 4    400005   COLEMAN         JOEL         NaN    NaN
# 5    400006     SMITH       DANIEL       DUANE     JR
# 6    400006     SMITH       DANIEL       DUANE    NaN
# 7    400006     SMITH       DANIEL     DUANEJR    NaN
# 8    400007      HILL      MICHAEL         NaN    NaN
# 9    400009    MCLAIN       JOSEPH         NaN    NaN
# 10   400014   BLEDSOE        TOMMY         LEE    NaN
# 11   400014   BLEDSOE         TONY          CL    NaN
# 12   400014   BLEDSOE         TONY     COLEMAN    NaN
# 13   400014   BLEDSOE         TONY  COLMAN LEE    NaN
# 14   400014   BLEDSOE         TONY         LEE    NaN
# 15   400019    BEVENS        KAREN     ANNETTE    NaN
# 16   400021     CLARK        JASON     DARNELL    NaN
# 17   400029     BROWN  CHRISTOPHER         NaN    NaN
# 18   400031     EATON       RONALD        GENE    NaN
# 19   400033   ENGLISH        SHERI         SUE    NaN

# %% [markdown]
# ## Schedule C - Sentence Data Layout
# ```
# =======================================================
# Incarcerated_Term_In_Years = 9999 indicates a death sen
# tence
#
# Incarcerated_Term_In_Years = 8888 indicates a life with
# out parole sentence
#
# Incarcerated_Term_In_Years = 7777 indicates a life sent
# ence
# =======================================================
#  Name                            Null?    Type
#  ------------------------------- -------- ----
#  DOC_NUM                         NOT NULL NUMBER(10)
#  STATUTE_CODE                    NOT NULL VARCHAR2(40)
#  SENTENCING_COUNTY                        VARCHAR2(40)
#  JS_DATE                                  DATE 'YYYYMMDD' (8)
#  CRF_NUMBER                               VARCHAR2(40)
#  INCARCERATED_TERM_IN_YEARS               NUMBER(10,2)
#  PROBATION_TERM_IN_YEARS                  NUMBER(10,2)
#  ```

# %%
file = 'data/Vendor_sentence_Sample_Text.dat'

# uncomment this line to use the full dataset
file = 'data/Vendor_sentence_Extract_Text.dat'


names =[
    "DOC_NUM",                   
    "STATUTE_CODE",              
    "SENTENCING_COUNTY",         
    "JS_DATE",                   
    "CRF_NUMBER",                
    "INCARCERATED_TERM_IN_YEARS",
    "PROBATION_TERM_IN_YEARS"
]

widths = [
    10,
    40,
    40,
    10,
    40,
    13,
    13
]

sentence_df = pd.read_fwf(file, 
    header=None,
    widths=widths,
    names=names)
                 
sentence_df.head(20)
# Out:
#     DOC_NUM STATUTE_CODE          SENTENCING_COUNTY    JS_DATE CRF_NUMBER  \
# 0       835     921-1720  POTTAWATOMIE COUNTY COURT  13-MAR-13   2010-300
# 1      1033    721-701.7         BRYAN COUNTY COURT  13-APR-20        1-0
# 2      1033    721-701.7         BRYAN COUNTY COURT  14-DEC-62   20-15645
# 3      2041     321-1731         TULSA COUNTY COURT  19-APR-77     77-240
# 4      2257      421-741         TULSA COUNTY COURT  03-MAR-64     20-393
# 5      2257   447-11-902         TULSA COUNTY COURT  24-OCT-94    94-4167
# 6      2266    321-801.A         TULSA COUNTY COURT  22-APR-64      2-513
# 7      2266    321-801.A         TULSA COUNTY COURT  22-APR-64      2-513
# 8      2739    963-2-402      OKLAHOMA COUNTY COURT  09-NOV-72     72-491
# 9      2739     921-1435      OKLAHOMA COUNTY COURT  14-NOV-72    72-1525
# 10     2748     621-1731      OKLAHOMA COUNTY COURT  16-MAR-88    87-7300
# 11     3223    821-801.A        CUSTER COUNTY COURT  17-JUN-35        1-0
# 12     3492      821-711        CARTER COUNTY COURT  09-JUL-84      84-45
# 13     3537     421-1115      GARFIELD COUNTY COURT  31-JUL-81    81-1654
# 14     3858    163-2-401         TULSA COUNTY COURT  10-NOV-94    94-2794
# 15     3858    163-2-401         TULSA COUNTY COURT  10-NOV-94    94-2794
# 16     3858     121-1283         TULSA COUNTY COURT  10-NOV-94    94-2794
# 17     3858  121-1289.16         TULSA COUNTY COURT  05-JUN-80     78-453
# 18     4028    921-701.7         LOGAN COUNTY COURT  05-JUN-85      84-39
# 19     4257     121-1287      OKLAHOMA COUNTY COURT  02-MAR-90    89-1553
#
#     INCARCERATED_TERM_IN_YEARS  PROBATION_TERM_IN_YEARS
# 0                          NaN                      1.5
# 1                       7777.0                      NaN
# 2                          NaN                     40.0
# 3                          NaN                      3.0
# 4                       7777.0                      NaN
# 5                          NaN                      1.0
# 6                         36.0                      NaN
# 7                         12.0                      NaN
# 8                          5.0                      NaN
# 9                          2.0                      NaN
# 10                         2.0                      NaN
# 11                      7777.0                      NaN
# 12                         NaN                     20.0
# 13                      8888.0                      NaN
# 14                        10.0                      NaN
# 15                         5.0                      NaN
# 16                         5.0                      NaN
# 17                         NaN                      3.0
# 18                      7777.0                      NaN
# 19                         5.0                      NaN

# %% [markdown]
# Schedule D - Offense Codes Layout
# =======================================================
#  ```
#  Name                            Null?    Type
#  ------------------------------- -------- ----
#  STATUTE_CODE                    NOT NULL VARCHAR2(38)
#  DESCRIPTION                     NOT NULL VARCHAR2(40)
#  VIOLENT                                  VARCHAR2(1)
# ```

# %%
file = 'data/Vendor_Offense_Extract_Text.dat'

names = ["STATUTE_CODE",
         "DESCRIPTION", 
         "VIOLENT",
]

widths = [
    38,
    40,
    1
]

offense_df = pd.read_fwf(file, 
    header=None,
    widths=widths,
    names=names)
                 
offense_df.head(20)
# Out:
#      STATUTE_CODE                               DESCRIPTION VIOLENT
# 0             0-0               UNKNOWN - FOR WARRANTS ONLY       N
# 1         10-1144         ACTS CAUSING JUVENILE DELINQUENCY       N
# 2         10-1627             DEPRIVATION OF LAWFUL CUSTODY       N
# 3           10-26   UNLAWFUL ASSUMPTION OF CUSTODY OF CHILD       N
# 4        10-404.1  SEX OFFENDER PROVIDING SERVICES TO CHILD       N
# 5          10-410  OPERATING CHILD CARE FACILITY W/O LICENS       N
# 6           10-71                       PATERNITY COMPLAINT       N
# 7         10-7103                   FAILURE TO REPORT CHILD       N
# 8         10-7115                               CHILD ABUSE       Y
# 9    10-7303-1.1B  REFUSE TO ASSUME CUSTODY OF CHILD IN DET       N
# 10  10A-2-7-611.B      PROHIBITED ITEMS JUVENILE FACILITIES       N
# 11       13-176.3      VIOLATING SECURITY OF COMMUNICATIONS       N
# 12     13-176.3.8    UNLAWFUL USE OF COMMUNICATION FACILITY       N
# 13       13-176.7   USE OF COMMUNICATION FACILITY TO COMMIT       N
# 14         15-751         CONSUMER PROTECTION ACT VIOLATION       N
# 15         15-753         CONSUMER PROTECTION ACT VIOLATION       N
# 16       15-765.3                         HOME REPAIR FRAUD       N
# 17         15-767      CONDUCT CLOSING OUT SALE W/O LICENSE       N
# 18      18-1020.F  CORP. FAILING TO FILE REAL ESTATE STATEM       N
# 19      18-552.11         FRAUDULENT USE OF NAME IN CHARITY       N

# %% [markdown]
# ## df summary
#
# - profile_df:  demographics
# - alias_df:
# - sentence_df: statute
# - offense_df

# %%
active_inmates = profile_df.query("STATUS == 'Active'")

joined_df = pd.merge(active_inmates, sentence_df, on='DOC_NUM', how='left')
active_inmates.head(20)
# Out:
#      DOC_NUM    LAST_NAME FIRST_NAME MIDDLE_NAME SUFFIX LAST_MOVE_DATE  \
# 6      27399       GARCIA       JOSE           L    NaN      11-JUL-16
# 55     49332     CAUGHRON     VICTOR           C    NaN      06-JUN-50
# 78     52432     MITCHELL     BENNIE           W    NaN      10-DEC-99
# 157    59131     WILLIAMS      JAMES           B    NaN      30-JUL-81
# 205    61758      ROWLAND      HENRY           B    NaN      29-NOV-99
# 226    62609         KARR     WESLEY           A    NaN      26-JAN-07
# 246    63500       BILLEY      SIMON           G    NaN      25-MAR-92
# 252    63615      VAUGHAN     DONALD         NaN    NaN      13-AUG-18
# 336    66653      TRAYLOR        LEE           W    NaN      27-JAN-17
# 379    68211  RITTERHOUSE     THOMAS           A    NaN      15-SEP-81
# 485    70853      WOOLSEY      BILLY           G    NaN      04-APR-07
# 557    72087      BARNETT     ROBERT           C    NaN      28-JUN-99
# 576    72424       WILSON     DONALD           R    NaN      30-AUG-91
# 672    74302      JOHNSON      CLAUD    ROBINSON    NaN      08-JUN-10
# 684    74422      PETROSS   MARSHALL           D    NaN      08-JUN-88
# 690    74496       DENTIS     BESSIE           M    NaN      18-SEP-92
# 768    75490        GLASS       GARY           M    NaN      07-JUL-88
# 769    75496       GADDIS     HOWARD         NaN    NaN      06-JUL-16
# 867    76252         BRAY  FREDERICK     DOUGLAS    NaN      08-DEC-08
# 883    76423       KOONCE     RONALD           T    NaN      19-AUG-09
#
#                                   FACILITY BIRTH_DATE SEX             RACE  \
# 6    NORTH FORK CORRECTIONAL CENTER ESCAPE  11-SEP-43   M         HISPANIC
# 55      OKLAHOMA STATE PENITENTIARY ESCAPE  18-MAY-23   M            WHITE
# 78      CENTRAL DISTRICT - SHERIDAN OFFICE  22-SEP-23   M              NaN
# 157              NORTHEAST DISTRICT OFFICE  03-NOV-61   M            WHITE
# 205                  TULSA COUNTY DISTRICT  20-MAR-39   M            BLACK
# 226              SOUTHEAST DISTRICT OFFICE  26-OCT-34   M            WHITE
# 246          SOUTHEAST DISTRICT CWC ESCAPE  01-MAR-44   M  NATIVE AMERICAN
# 252     JAMES CRABTREE CORRECTIONAL CENTER  03-JUN-40   M            WHITE
# 336        JOSEPH HARP CORRECTIONAL CENTER  19-JAN-39   M            BLACK
# 379              NORTHEAST DISTRICT OFFICE  05-NOV-43   M            WHITE
# 485        JOSEPH HARP CORRECTIONAL CENTER  04-JUL-41   M            WHITE
# 557     CENTRAL DISTRICT - SHERIDAN OFFICE  09-MAY-38   M            BLACK
# 576          LEXINGTON CORRECTIONAL CENTER  08-NOV-44   M            WHITE
# 672              SOUTHEAST DISTRICT OFFICE  28-MAY-41   M  NATIVE AMERICAN
# 684              NORTHEAST DISTRICT OFFICE  16-FEB-47   F            WHITE
# 690                  TULSA COUNTY DISTRICT  13-JUN-45   F            WHITE
# 768     CENTRAL DISTRICT - SHERIDAN OFFICE  13-SEP-49   M            WHITE
# 769         NORTH FORK CORRECTIONAL CENTER  17-MAY-42   M            BLACK
# 867              SOUTHWEST DISTRICT OFFICE  27-MAY-48   M            BLACK
# 883        JOSEPH HARP CORRECTIONAL CENTER  25-NOV-43   M            WHITE
#
#            HAIR  HEIGHT_FT  HEIGHT_IN  WEIGHT    EYE  STATUS
# 6         BLACK        5.0        8.0   165.0  BROWN  Active
# 55        BLACK        5.0       11.0   165.0  BROWN  Active
# 78          NaN        NaN        NaN     NaN    NaN  Active
# 157  GRAY, ETC.        5.0        7.0   150.0  BROWN  Active
# 205  GRAY, ETC.        5.0       11.0   230.0  BROWN  Active
# 226        GRAY        6.0        0.0   180.0   BLUE  Active
# 246       BLACK        5.0        9.0   186.0  BROWN  Active
# 252  GRAY, ETC.        5.0       11.0   180.0  HAZEL  Active
# 336       BLACK        5.0        7.0   159.0  BROWN  Active
# 379       BROWN        5.0        9.0   192.0  BROWN  Active
# 485       BLACK        6.0        0.0   165.0   BLUE  Active
# 557       BLACK        5.0       11.0   170.0    N/R  Active
# 576  GRAY, ETC.        5.0       10.0   155.0  GREEN  Active
# 672       BROWN        5.0       11.0   262.0  BROWN  Active
# 684       BROWN        5.0        6.0   152.0  HAZEL  Active
# 690       BROWN        5.0        2.0   150.0   BLUE  Active
# 768       BROWN        5.0       11.0   154.0   BLUE  Active
# 769       BLACK        5.0        6.0   147.0  BROWN  Active
# 867       BLACK        5.0       11.0   189.0  BROWN  Active
# 883       BROWN        5.0        9.0   135.0   BLUE  Active

# %%
import numpy as np

import matplotlib.pyplot as plt


graph_df = active_inmates.groupby(['RACE'])['DOC_NUM'].count()
graph_df.plot.pie(y='RACE', figsize=(5, 5))

# %%
facility_graph = active_inmates.groupby(['FACILTY'])['DOC_NUM'].count()

facility_graph.plot.bar(y='FACILITY', figsize=(5, 5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-f36699dc9bec> in <module>
# ----> 1 facility_graph = active_inmates.groupby(['FACILTY'])['DOC_NUM'].count()
#       2
#       3 facility_graph.plot.bar(y='FACILITY', figsize=(5, 5))
#
# ~/projects/venvs/odoc/lib/python3.6/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# ~/projects/venvs/odoc/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     408                 sort=sort,
#     409                 observed=observed,
# --> 410                 mutated=self.mutated,
#     411             )
#     412
#
# ~/projects/venvs/odoc/lib/python3.6/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     598                 in_axis, name, level, gpr = False, None, gpr, None
#     599             else:
# --> 600                 raise KeyError(gpr)
#     601         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     602             # Add key to exclusions
#
# KeyError: 'FACILTY'
